# %% [markdown]
# <a href="https://colab.research.google.com/github/Manishkancharla/Statistics-Basic-Assignment/blob/main/Statistics_Advance_1_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Define the z-statistic and explain its relationship to the standard normal distribution. How is the
# z-statistic used in hypothesis testing?
#
# A) The z-statistic (or z-score) is a statistical measure that quantifies the number of standard deviations a data point or sample statistic is from the mean of the population. It is commonly used in statistics to standardize data points, compare them to a standard normal distribution, and perform hypothesis testing.
#
# The formula for the z-statistic is:
#
# 𝑧
# =
# 𝑋
# −
# 𝜇
# 𝜎
# z=
# σ
# X−μ
# ​
#
# Where:
#
# 𝑋
# X: The observed data point or sample mean
# 𝜇
# μ: The population mean
# 𝜎
# σ: The population standard deviation
# If the z-statistic is calculated for a sample mean, the formula becomes:
#
# 𝑧
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# 𝑛
# z=
# n
# ​
#
# σ
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#  : The sample mean
# 𝑛
# n: The sample size
#
#
#
#
#
#
# Relationship to the Standard Normal Distribution
# The z-statistic represents a value on the standard normal distribution, which is a normal distribution with:
# A mean (
# 𝜇
# μ) of 0
# A standard deviation (
# 𝜎
# σ) of 1
# The z-statistic tells us how far and in which direction a data point is from the mean in terms of standard deviations.
# The area under the curve of the standard normal distribution corresponds to probabilities. For example:
# A z-score of 0 means the value is exactly at the mean.
# A z-score of +1 or -1 means the value is one standard deviation above or below the mean.
# Approximately 68% of values fall within ±1 standard deviation, 95% within ±2, and 99.7% within ±3 (empirical rule).
#
#
#
#
#
# How is the Z-Statistic Used in Hypothesis Testing?
# The z-statistic is a critical component of hypothesis testing, particularly for tests involving population means or proportions when the population standard deviation is known.
#
# Steps in Hypothesis Testing with the Z-Statistic:
# State the Hypotheses:
#
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): A statement of no effect or no difference.
# Alternative Hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ): A statement that contradicts the null hypothesis.
# Choose the Significance Level (
# 𝛼
# α):
#
# Commonly used levels are 0.05 (5%) or 0.01 (1%).
# Calculate the Z-Statistic:
#
# Use the formula
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# 𝑛
# n
# ​
#
# σ
# ​
#
# X
# ˉ
#  −μ
# ​
#   for the test statistic.
# Determine the Critical Value or P-Value:
#
# Use the standard normal distribution table to find the critical z-value or calculate the p-value based on the observed z-statistic.
# Make a Decision:
#
# If the z-statistic exceeds the critical value (or if the p-value is less than
# 𝛼
# α), reject the null hypothesis.
# Otherwise, fail to reject the null hypothesis.

# %% [markdown]
# 2)  What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is
# very small (e.g., 0.01)?
#
# A) The p-value is a probability that measures the strength of evidence against the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) in a hypothesis test. It represents the likelihood of obtaining a test statistic at least as extreme as the one observed, assuming the null hypothesis is true.
#
# P-Value
# =
# 𝑃
# (
# Observed or more extreme results |
# 𝐻
# 0
#  is true
# )
# P-Value=P(Observed or more extreme results | H
# 0
# ​
#   is true)
# How is the P-Value Used in Hypothesis Testing?
# The p-value is used to decide whether to reject or fail to reject the null hypothesis:
#
# Set the Significance Level (
# 𝛼
# α):
#
# Common values are
# 𝛼
# =
# 0.05
# α=0.05 (5%) or
# 𝛼
# =
# 0.01
# α=0.01 (1%).
# Compare the P-Value to
# 𝛼
# α:
#
# If
# 𝑝
# ≤
# 𝛼
# p≤α: Reject the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ). The results are statistically significant.
# If
# 𝑝
# >
# 𝛼
# p>α: Fail to reject the null hypothesis. There is insufficient evidence to conclude a significant effect or difference.
# Interpretation:
#
# A small p-value indicates that the observed data is unlikely under the null hypothesis, providing strong evidence to reject
# 𝐻
# 0
# H
# 0
# ​
#  .
# A large p-value suggests the data is consistent with the null hypothesis.
# What Does It Mean if the P-Value is Very Small (e.g., 0.01)?
# A very small p-value (e.g.,
# 𝑝
# =
# 0.01
# p=0.01) means:
#
# Strong Evidence Against
# 𝐻
# 0
# H
# 0
# ​
#  :
#
# The probability of observing the data (or something more extreme) if the null hypothesis were true is only 1%.
# Statistical Significance:
#
# If
# 𝛼
# =
# 0.05
# α=0.05, then
# 𝑝
# <
# 𝛼
# p<α, and the null hypothesis is rejected.
# This implies that the observed effect or difference is unlikely to be due to chance.
# Practical Implication:
#
# The result is statistically significant, and there is strong evidence to support the alternative hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ).

# %% [markdown]
# 3)  Compare and contrast the binomial and Bernoulli distributions?
#
# A) Bernoulli Distribution:
#
# Represents a single experiment or trial that has only two possible outcomes: success (
# 1
# 1) or failure (
# 0
# 0).
# It is the simplest discrete probability distribution.
# Example: Tossing a coin once.
# Probability mass function (PMF):
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# {
# 𝑝
# if
# 𝑥
# =
# 1
# ,
# 1
# −
# 𝑝
# if
# 𝑥
# =
# 0
# ,
# P(X=x)={
# p
# 1−p
# ​
#
# if x=1,
# if x=0,
# ​
#
# where
# 0
# ≤
# 𝑝
# ≤
# 1
# 0≤p≤1.
#
# Binomial Distribution:
#
# Represents the number of successes in a fixed number of independent Bernoulli trials.
# Example: Tossing a coin 10 times and counting the number of heads.
# PMF:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# ,
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#  ,k=0,1,2,…,n
# where:
#
# 𝑛
# n is the number of trials,
# 𝑘
# k is the number of successes,
# 𝑝
# p is the probability of success in a single trial.

# %% [markdown]
# 4)  Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli
# distribution?
#
# A) Conditions for Using the Binomial Distribution
# The binomial distribution is used under the following conditions:
#
# Fixed Number of Trials (
# 𝑛
# n):
# There must be a predefined number of independent trials (
# 𝑛
# n).
#
# Only Two Outcomes Per Trial:
# Each trial results in either a success or a failure.
#
# Constant Probability of Success (
# 𝑝
# p):
# The probability of success (
# 𝑝
# p) remains the same across all trials.
#
# Independence of Trials:
# The outcome of one trial does not affect the outcome of another trial.
#
# Counting the Number of Successes:
# The variable of interest is the total number of successes (
# 𝑘
# k) in
# 𝑛
# n trials.
#
# How the Binomial Distribution Relates to the Bernoulli Distribution
# The binomial distribution builds directly on the Bernoulli distribution:
#
# Bernoulli as a Single Trial:
# A Bernoulli distribution represents a single trial with two outcomes (success or failure).
# Example: Tossing a coin once to get heads or tails.
#
# PMF of Bernoulli:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# {
# 𝑝
# if
# 𝑥
# =
# 1
# ,
# 1
# −
# 𝑝
# if
# 𝑥
# =
# 0
# ,
# P(X=x)={
# p
# 1−p
# ​
#
# if x=1,
# if x=0,
# ​
#
# where
# 0
# ≤
# 𝑝
# ≤
# 1
# 0≤p≤1.
# Binomial as Multiple Bernoulli Trials:
# A binomial distribution is the sum of
# 𝑛
# n independent Bernoulli trials with the same probability
# 𝑝
# p.
# Example: Tossing a coin
# 𝑛
# =
# 10
# n=10 times and counting the number of heads.
#
# PMF of Binomial:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# ,
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#  ,k=0,1,2,…,n
# where:
# (
# 𝑛
# 𝑘
# )
# =
# 𝑛
# !
# 𝑘
# !
# (
# 𝑛
# −
# 𝑘
# )
# !
# (
# k
# n
# ​
#  )=
# k!(n−k)!
# n!
# ​
#  ,
# 𝑘
# k is the number of successes,
# 𝑝
# p is the probability of success.
# Relationship:
#
# A Bernoulli distribution is a special case of the binomial distribution where
# 𝑛
# =
# 1
# n=1.
# In other words, a single Bernoulli trial (
# 𝑛
# =
# 1
# n=1) can be thought of as a binomial distribution with
# 𝑛
# =
# 1
# n=1.

# %% [markdown]
# 5)  What are the key properties of the Poisson distribution, and when is it appropriate to use this
# distribution?
#
# A) The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time, space, or other dimensions, under certain conditions. Here are its key properties:
#
# Discrete Nature:
# The Poisson distribution applies to scenarios where the random variable is the count of events, e.g., the number of emails received in an hour.
#
# Parameter:
# It is characterized by a single parameter
# 𝜆
# λ, which represents the average rate of events in the given interval.
#
# Mean (
# 𝜇
# μ) =
# 𝜆
# λ,
# Variance (
# 𝜎
# 2
# σ
# 2
#  ) =
# 𝜆
# λ.
# Probability Mass Function (PMF):
# The probability of observing
# 𝑘
# k events is given by:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# ,
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#  ,k=0,1,2,…
# where:
#
# 𝑒
# e is the base of the natural logarithm (
# ≈
# 2.718
# ≈2.718),
# 𝑘
# !
# k! is the factorial of
# 𝑘
# k.
# Independence:
# Events occur independently of each other.
#
# Non-Negative Counts:
# The random variable
# 𝑋
# X represents counts, so it only takes non-negative integer values (
# 0
# ,
# 1
# ,
# 2
# ,
# …
# 0,1,2,…).
#
# Rare Events:
# It is suitable for modeling rare events when the probability of occurrence in a small interval is very low but the number of intervals is large.

# %% [markdown]
# 6)  Define the terms "probability distribution" and "probability density function" (PDF). How does a
# PDF differ from a probability mass function (PMF)?
#
# A) A probability distribution describes how probabilities are assigned to the possible values of a random variable. It provides a mathematical function that maps outcomes to their likelihood of occurrence.
#
# For Discrete Variables: The distribution specifies the probability of each distinct value.
# For Continuous Variables: The distribution specifies how probabilities are distributed over a continuous range of values.
# Probability Density Function (PDF)
# A probability density function (PDF) is a function that describes the relative likelihood of a continuous random variable taking on a particular value. The key properties of a PDF are:
#
# Non-Negative:
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0 for all
# 𝑥
# x.
#
# Integral Equals 1:
# The total area under the PDF curve over the entire range of possible values equals 1:
#
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
# Describes Likelihood, Not Direct Probability:
# The PDF does not give the probability of a specific value (since for continuous variables,
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0), but it indicates the relative likelihood of values within an interval. The probability of
# 𝑋
# X falling in an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is given by:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# Probability Mass Function (PMF)
# A probability mass function (PMF) applies to discrete random variables. It assigns a probability to each possible value of the random variable.
#
# Non-Negative:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# ≥
# 0
# P(X=x)≥0.
#
# Sum Equals 1:
# The total probability across all possible values is 1:
#
# ∑
# 𝑥
# ∈
# 𝑆
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# x∈S
# ∑
# ​
#  P(X=x)=1
# where
# 𝑆
# S is the set of all possible values of
# 𝑋
# X.
#
# Direct Probability:
# For a discrete variable
# 𝑋
# X, the PMF gives the exact probability of
# 𝑋
# X taking on a specific value
# 𝑥
# x:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# (
# 𝑥
# )
# P(X=x)=p(x)

# %% [markdown]
# 7) Explain the Central Limit Theorem (CLT) with example?
#
# A) The Central Limit Theorem (CLT) is a fundamental concept in statistics. It states that, for a sufficiently large sample size, the sampling distribution of the sample mean will approach a normal distribution (bell-shaped curve), regardless of the population's original distribution.
#
# Key Features of the CLT:
# Sample Size:
# The theorem holds true when the sample size (
# 𝑛
# n) is sufficiently large, typically
# 𝑛
# ≥
# 30
# n≥30.
#
# Population Distribution:
# The population from which samples are drawn can have any distribution (e.g., uniform, skewed, exponential).
#
# Mean and Standard Deviation:
#
# The mean of the sampling distribution (
# 𝜇
# 𝑋
# ˉ
# μ
# X
# ˉ
#
# ​
#  ) equals the population mean (
# 𝜇
# μ).
# The standard deviation of the sampling distribution (called the standard error) is:
# 𝜎
# 𝑋
# ˉ
# =
# 𝜎
# 𝑛
# σ
# X
# ˉ
#
# ​
#  =
# n
# ​
#
# σ
# ​
#
# where
# 𝜎
# σ is the population standard deviation and
# 𝑛
# n is the sample size.
# Implications:
#
# The larger the sample size, the closer the sampling distribution of the mean approximates a normal distribution.
# This allows us to use statistical tools based on normality, even if the population distribution is unknown or not normal.
#
# Example to Illustrate the CLT
# Scenario:
# Suppose you are studying the average time (in minutes) people spend on a social media app daily. The population distribution is right-skewed, as most users spend little time, but a few users spend many hours.
#
# Population Mean (
# 𝜇
# μ): 50 minutes.
# Population Standard Deviation (
# 𝜎
# σ): 15 minutes.
# Step 1: Draw Random Samples
# Take random samples of size
# 𝑛
# =
# 50
# n=50.
#
# Step 2: Compute the Sample Means
# For each sample, compute the sample mean (
# 𝑋
# ˉ
# X
# ˉ
#  ).
#
# Step 3: Observe the Distribution of Sample Means
# The distribution of these sample means will approximate a normal distribution.
# The mean of the sampling distribution (
# 𝜇
# 𝑋
# ˉ
# μ
# X
# ˉ
#
# ​
#  ) will still be 50 minutes.
# The standard error will be:
# 𝜎
# 𝑋
# ˉ
# =
# 𝜎
# 𝑛
# =
# 15
# 50
# ≈
# 2.12
# σ
# X
# ˉ
#
# ​
#  =
# n
# ​
#
# σ
# ​
#  =
# 50
# ​
#
# 15
# ​
#  ≈2.12
# Step 4: Implication
# Even though the population distribution is skewed, the sampling distribution of the sample mean is approximately normal.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulating a skewed population
np.random.seed(42)
population = np.random.exponential(scale=10, size=10000)  # Exponential distribution

# Sampling parameters
sample_size = 50
num_samples = 1000
sample_means = []

# Collect sample means
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=True)
    sample_means.append(np.mean(sample))

# Plotting
plt.figure(figsize=(12, 6))

# Population distribution
plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='skyblue', alpha=0.7)
plt.title("Population Distribution (Skewed)")

# Sampling distribution of the mean
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, color='orange', alpha=0.7)
plt.title("Sampling Distribution of the Mean (Approximately Normal)")

plt.show()

# %% [markdown]
# 8) Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be applied instead?
#
# A) Both z-scores and t-scores are statistical measures used to standardize data and compare it across distributions, but they are used in different scenarios and have distinct properties.
#
# Z-Score
# Definition:
# A z-score represents the number of standard deviations a data point or sample mean is from the population mean.
# Formula:
#
# 𝑧
# =
# 𝑋
# −
# 𝜇
# 𝜎
# z=
# σ
# X−μ
# ​
#
# where:
#
# 𝑋
# X = observed value or sample mean,
# 𝜇
# μ = population mean,
# 𝜎
# σ = population standard deviation.
# When to Use:
#
# The population standard deviation (
# 𝜎
# σ) is known.
# The sample size is large (
# 𝑛
# ≥
# 30
# n≥30) due to the Central Limit Theorem.
# The population is assumed to follow a normal distribution or the sample size is large enough to approximate normality.
# Applications:
#
# Standardized tests (e.g., SAT scores).
# Comparing individual data points to a known population.
# T-Score
# Definition:
# A t-score (from the Student's t-distribution) is used when the sample standard deviation (
# 𝑠
# s) is used instead of the population standard deviation (
# 𝜎
# σ). It adjusts for the uncertainty introduced by estimating the standard deviation.
# Formula:
#
# 𝑡
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# 𝑛
# t=
# n
# ​
#
# s
# ​
#
# X
# ˉ
#  −μ
# ​
#
# where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean,
# 𝜇
# μ = population mean (or hypothesized mean),
# 𝑠
# s = sample standard deviation,
# 𝑛
# n = sample size.
# When to Use:
#
# The population standard deviation (
# 𝜎
# σ) is unknown.
# The sample size is small (
# 𝑛
# <
# 30
# n<30).
# The population follows a normal distribution (or the sample size is small and normality is assumed).
# Applications:
#
# Hypothesis testing when dealing with small sample sizes.
# Confidence intervals for small samples or unknown population variance.

# %% [markdown]
# 9) Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample
# size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to
# reject the null hypothesis?
#
#  Task: Write Python code to calculate the z-score and p-value for the given data.
#
# Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing?

# %%
from scipy.stats import norm

# Given data
sample_mean = 105
population_mean = 100
std_dev = 15
sample_size = 25
significance_level = 0.05

# Calculate standard error
standard_error = std_dev / (sample_size ** 0.5)

# Calculate z-score
z_score = (sample_mean - population_mean) / standard_error

# Calculate p-value (two-tailed test)
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Decision: Compare p-value with significance level
decision = "Reject the null hypothesis" if p_value < significance_level else "Fail to reject the null hypothesis"

# Print results
print(f"Z-Score: {z_score:.2f}")
print(f"P-Value: {p_value:.4f}")
print(f"Decision: {decision}")
# Out:
# Z-Score: 1.67
# P-Value: 0.0956
# Decision: Fail to reject the null hypothesis

# %% [markdown]
# 10)  Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?
#
# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.
#
# Objective: Understand the properties of a binomial distribution and verify them through simulation?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n_trials = 10
p_success = 0.6
n_samples = 1000

# Simulate binomial distribution
samples = np.random.binomial(n_trials, p_success, n_samples)

# Calculate expected mean and variance
expected_mean = n_trials * p_success
expected_variance = n_trials * p_success * (1 - p_success)

# Calculate sample mean and variance
sample_mean = np.mean(samples)
sample_variance = np.var(samples)

# Plot the distribution
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=range(n_trials + 2), density=True, alpha=0.7, color='blue', edgecolor='black')
plt.title("Binomial Distribution (n=10, p=0.6)")
plt.xlabel("Number of successes")
plt.ylabel("Probability")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Output the expected and sample mean and variance
expected_mean, expected_variance, sample_mean, sample_variance
# Out:
# (6.0, 2.4000000000000004, 5.975, 2.504375)
